# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np


ad_birth_path = "./data/adolescentBirthRate.csv" 
skilled_attender_path = "./data/birthAttendedBySkilledPersonal.csv" 
IMR_path = "./data/infantMortalityRate.csv" 
neonatal_path = "./data/neonatalMortalityRate.csv" 
u5_mortality_path = "./data/under5MortalityRate.csv"

# %%
u5_mortality_rates_df = pd.read_csv(u5_mortality_path, encoding = "utf-8")
IMR_df = pd.read_csv(IMR_path, encoding = "utf-8")
neonatal_df = pd.read_csv(neonatal_path, encoding = "utf-8")
skilled_attender_path = pd.read_csv(skilled_attender_path, encoding = "utf-8")
ad_birth_path = pd.read_csv(ad_birth_path, encoding = "utf-8")

# %%
neonatal_df
# Out:
#          Location  Period                                       Indicator  \
# 0     Afghanistan    2019  Neonatal mortality rate (per 1000 live births)
# 1     Afghanistan    2018  Neonatal mortality rate (per 1000 live births)
# 2     Afghanistan    2017  Neonatal mortality rate (per 1000 live births)
# 3     Afghanistan    2016  Neonatal mortality rate (per 1000 live births)
# 4     Afghanistan    2015  Neonatal mortality rate (per 1000 live births)
# ...           ...     ...                                             ...
# 9130     Zimbabwe    1969  Neonatal mortality rate (per 1000 live births)
# 9131     Zimbabwe    1968  Neonatal mortality rate (per 1000 live births)
# 9132     Zimbabwe    1967  Neonatal mortality rate (per 1000 live births)
# 9133     Zimbabwe    1966  Neonatal mortality rate (per 1000 live births)
# 9134     Zimbabwe    1965  Neonatal mortality rate (per 1000 live births)
#
#             Dim1        First Tooltip
# 0     Both sexes  35.86 [27.77-45.18]
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-42b96e98a2cc> in <module>
# ----> 1 neonatal_df["First Tooltip"] = neonatal_df["First Tooltip"].map("{:,.2}".format)
#       2 neonatal_df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3968         dtype: object
#    3969         """
# -> 3970         new_values = super()._map_values(arg, na_action=na_action)
#    3971         return self._constructor(new_values, index=self.index).__finalize__(
#    3972             self, method="map"
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...
